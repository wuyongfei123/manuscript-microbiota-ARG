# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/data/public/miniforge3/envs/snk/lib/python3.12/site-packages', '/data/yeyun/projects/duck/16s_its/16s_test2/workflow/rules', '/data/yeyun/projects/duck/16s_its/16s_test2/workflow', '/data/public/miniforge3/envs/snk/bin', '/data/public/miniforge3/envs/snk/lib/python3.12', '/data/public/miniforge3/envs/snk/lib/python3.12/lib-dynload', '/data/public/miniforge3/envs/snk/lib/python3.12/site-packages', '/home/yeyun/.cache/snakemake/snakemake/source-cache/runtime-cache/tmp3zx2f579/file/data/yeyun/projects/duck/16s_its/16s_test2/workflow/rules/notebooks', '/data/yeyun/projects/duck/16s_its/16s_test2/workflow/rules/notebooks']); import pickle; snakemake = pickle.loads(b"\x80\x04\x95\x9f\x05\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94\x8c'results/feature_table/feature_table.qza\x94a}\x94(\x8c\x06_names\x94}\x94\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x10\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x16)}\x94\x8c\x05_name\x94h\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c'results/feature_table/feature_table.tsv\x94a}\x94(h\x0c}\x94h\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x0c}\x94h\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94\x8c#results/feature_table/feature_table\x94a}\x94(h\x0c}\x94\x8c\x06prefix\x94K\x00N\x86\x94sh\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94b\x8c\x06prefix\x94hCub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x0c}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bhZK\x01h\\K\x01h^hWub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94}\x94(h\x0c}\x94h\x0e]\x94(h\x10h\x11eh\x10h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x10sNt\x94bh\x11h\x14h\x16\x85\x94R\x94(h\x16)}\x94h\x1ah\x11sNt\x94bub\x8c\x06config\x94}\x94(\x8c\x10classifiers_file\x94\x8c0datas/classifiers/silva-138-99-nb-classifier.qza\x94\x8c\x15samples_metadata_file\x94\x8c\x1dconfigs/16s-raw-metadata..txt\x94\x8c\x18feature_table_build_mode\x94\x8c\x05dada2\x94\x8c\tdata_type\x94\x8c\x0316S\x94\x8c\x0cdada2_params\x94}\x94(\x8c\x0btrunc_len_f\x94M(\x01\x8c\x0btrunc_len_r\x94M(\x01\x8c\x0btrim_left_f\x94K\x1b\x8c\x0btrim_left_r\x94K\x1b\x8c\x0cextra_params\x94\x8c7 --p-retain-all-samples --p-max-ee-f 5 --p-max-ee-r 10 \x94uu\x8c\x04rule\x94\x8c\x11feature_table2tsv\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cD/data/yeyun/projects/duck/16s_its/16s_test2/workflow/rules/notebooks\x94ub."); from snakemake.logging import logger;  logger.printshellcmds = False; import os; os.chdir(r'/data/yeyun/projects/duck/16s_its/16s_test2');
######## snakemake preamble end #########

# %%
# start coding here
from qiime2 import Artifact
import biom
import pandas as pd

# %%
tmp = Artifact.load(snakemake.input[0])

# %%
tmp.view(pd.DataFrame).T.to_csv(snakemake.output[0], sep='\t')
